# %%
import pandas as pd

# %%
Stock_prices = pd.read_csv(r"C:\Users\Admin\Downloads\Stock_prices.csv")

# %%
Stock_prices
# Out:
#        symbol        date      open      high       low     close    volume
# 0         AAL    1/2/2014   25.0700   25.8200   25.0600   25.3600   8998943
# 1        AAPL    1/2/2014   79.3828   79.5756   78.8601   79.0185  58791957
# 2         AAP    1/2/2014  110.3600  111.8800  109.2900  109.7400    542711
# 3        ABBV    1/2/2014   52.1200   52.3300   51.5200   51.9800   4569061
# 4         ABC    1/2/2014   70.1100   70.2300   69.4800   69.8900   1148391
# ...       ...         ...       ...       ...       ...       ...       ...
# 497467    XYL  12/29/2017   68.5300   68.8000   67.9200   68.2000   1046677
# 497468    YUM  12/29/2017   82.6400   82.7100   81.5900   81.6100   1347613
# 497469    ZBH  12/29/2017  121.7500  121.9500  120.6200  120.6700   1023624
# 497470   ZION  12/29/2017   51.2800   51.5500   50.8100   50.8300   1261916
# 497471    ZTS  12/29/2017   72.5500   72.7600   72.0400   72.0400   1704122
#
# [497472 rows x 7 columns]

# %%
 Stock_prices.head()
# Out:
#   symbol      date      open      high       low     close    volume
# 0    AAL  1/2/2014   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  1/2/2014   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  1/2/2014  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  1/2/2014   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  1/2/2014   70.1100   70.2300   69.4800   69.8900   1148391

# %%
Stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497472 entries, 0 to 497471
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  497472 non-null  object
#  1   date    497472 non-null  object
#  2   open    497461 non-null  float64
#  3   high    497464 non-null  float64
#  4   low     497464 non-null  float64
#  5   close   497472 non-null  float64
#  6   volume  497472 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 26.6+ MB

# %%
Stock_prices.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %%
Stock_prices.ffill(inplace=True)
Stock_prices.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
Stock_prices.duplicated().sum()
# Out:
# np.int64(0)

# %%
Stock_prices.describe()
# Out:
#                 open           high            low          close  \
# count  497472.000000  497472.000000  497472.000000  497472.000000
# mean       86.351835      87.131986      85.551898      86.369082
# std       101.470449     102.311361     100.570269     101.472407
# min         1.620000       1.690000       1.500000       1.590000
# 25%        41.690000      42.090000      41.280000      41.703750
# 50%        64.970000      65.560000      64.350000      64.980000
# 75%        98.410000      99.230000      97.580000      98.420000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  4.974720e+05
# mean   4.253611e+06
# std    8.232139e+06
# min    0.000000e+00
# 25%    1.080166e+06
# 50%    2.084896e+06
# 75%    4.271928e+06
# max    6.182376e+08

# %%
Stock_prices['symbol'].unique()
# Out:
# array(['AAL', 'AAPL', 'AAP', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI',
#        'ADM', 'ADP', 'ADSK', 'ADS', 'AEE', 'AEP', 'AES', 'AET', 'AFL',
#        'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK',
#        'ALLE', 'ALL', 'ALXN', 'AMAT', 'AMD', 'AME', 'AMGN', 'AMG', 'AMP',
#        'AMT', 'AMZN', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC',
#        'APD', 'APH', 'ARE', 'ARNC', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK',
#        'AXP', 'AYI', 'AZO', 'A', 'BAC', 'BAX', 'BA', 'BBT', 'BBY', 'BDX',
#        'BEN', 'BF.B', 'BIIB', 'BK', 'BLK', 'BLL', 'BMY', 'BRK.B', 'BSX',
#        'BWA', 'BXP', 'CAG', 'CAH', 'CAT', 'CA', 'CBG', 'CBOE', 'CBS',
#        'CB', 'CCI', 'CCL', 'CDNS', 'CELG', 'CERN', 'CF', 'CHD', 'CHK',
#        'CHRW', 'CHTR', 'CINF', 'CI', 'CLX', 'CL', 'CMA', 'CMCSA', 'CME',
#        'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COL', 'COO',
#        'COP', 'COST', 'COTY', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTL',
# ...

# %%
Stock_prices.corr(numeric_only=True)
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999937  0.999924  0.999852 -0.148721
# high    0.999937  1.000000  0.999905  0.999917 -0.148341
# low     0.999924  0.999905  1.000000  0.999921 -0.149281
# close   0.999852  0.999917  0.999921  1.000000 -0.148839
# volume -0.148721 -0.148341 -0.149281 -0.148839  1.000000

# %%
import matplotlib.pyplot as plt

Stock_prices['close'].hist()
plt.title("Distribution of Closing Prices")
plt.show()

# %%
plt.scatter(Stock_prices['open'], Stock_prices['close'])
plt.xlabel("Open Price")
plt.ylabel("Close Price")
plt.title("Open vs Close Price")
plt.show()

# %%
stock_sample = stock.iloc[::100]  # take every 100th row

plt.plot(stock_sample['date'], stock_sample['close'])
plt.title("Stock Price Over Time")
plt.xticks(rotation=45)
plt.show()

# %%
Stock_prices.describe()
# Out:
#                 open           high            low          close  \
# count  497472.000000  497472.000000  497472.000000  497472.000000
# mean       86.351835      87.131986      85.551898      86.369082
# std       101.470449     102.311361     100.570269     101.472407
# min         1.620000       1.690000       1.500000       1.590000
# 25%        41.690000      42.090000      41.280000      41.703750
# 50%        64.970000      65.560000      64.350000      64.980000
# 75%        98.410000      99.230000      97.580000      98.420000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  4.974720e+05
# mean   4.253611e+06
# std    8.232139e+06
# min    0.000000e+00
# 25%    1.080166e+06
# 50%    2.084896e+06
# 75%    4.271928e+06
# max    6.182376e+08
